# %% [markdown]
# # Eine Einführung in Python und das Pandas-Library
# # Workshop April 2017

# %% [markdown]
# 1. Jupyter Notebooks
# 2. Python
# 3. Pandas - Einführung
# 4. Matplotlib
# 5. Pandas - Merging

# %% [markdown]
# ## 1. Was ist Jupyter Notebooks

# %% [markdown]
# The [Jupyter Notebook](http://jupyter.org/) is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and explanatory text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, machine learning and much more.

# %% [markdown]
# Code cells

# %%
print('hello world')

# %% [markdown]
# Text cells, markup [(Cheat Sheet)](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)

# %% [markdown]
# # Hello World
# ## Hello World
# ### Hello World
# #### Hello World
# ##### Hello World
# Hello World

# %% [markdown]
# ## 2. Was ist Python?

# %% [markdown]
# An interpreted language, Python has a design philosophy which emphasizes code readability (notably using whitespace indentation to delimit code blocks rather than curly braces or keywords), and a syntax which allows programmers to express concepts in fewer lines of code than possible in languages such as C++ or Java.

# %% [markdown]
# ### Data types

# %% [markdown]
# Strings = Text

# %%
'ich bin ein string'

# %% [markdown]
# Integers = Nummer

# %%
3

# %% [markdown]
# Floats = Nummern mit Dezimalstellen

# %%
3.898798

# %% [markdown]
# ### Variabeln

# %%
hallo = 'Du'

# %%
hallo

# %%
Du = 'ich'

# %%
Du

# %%
hallo + Du

# %% [markdown]
# ## 3. Was ist Pandas?

# %% [markdown]
# Hintergrund: [Mehr dazu hier](http://pandas.pydata.org/). Im Grunde ist es all das, was Excel sein möchte. Nämlich eine Tabellen-Kalkulation, die wirklich Sinn macht.

# %% [markdown]
# Importieren wir Pandas, denn ganz alleine kann Python ziemlich wenig.

# %%
import pandas as pd

# %% [markdown]
# Schauen wir uns kürzlich publizierte [Betreibungsstatistik](https://www.bfs.admin.ch/bfs/de/home/aktuell/neue-veroeffentlichungen.assetdetail.2240938.html) des Bundes an.
# - In welchem Kanton haben die Betreibungen prozentual am meisten zugenommen (1995 bis 2016)?
# - In welchem Kanton hat es am meisten Betreibungen pro Haushalt?

# %%
df = pd.read_excel('je-d-06.02.03.02.xls')

# %%
df.head()

# %% [markdown]
# Schneiden wir uns die Tabelle zurecht

# %%
df = pd.read_excel('je-d-06.02.03.02.xls', skiprows=5, skipfooter=8)

# %% [markdown]
# Schauen wir uns die ersten Zeilen an

# %%
df.head(10)
# Out:
#           Unnamed: 0       1995       1996       1997       1998       1999  \
# 0                NaN        NaN        NaN        NaN        NaN        NaN
# 1                NaN        NaN        NaN        NaN        NaN        NaN
# 2              Total  1770026.0  1832888.0  2048470.0  2127210.0  2067974.0
# 3                NaN        NaN        NaN        NaN        NaN        NaN
# 4    Genferseeregion   479160.0   502708.0   535614.0   556002.0   559787.0
# 5              Waadt   230502.0   242118.0   256017.0   267663.0   248490.0
# 6             Wallis   105695.0   109941.0   117929.0   117347.0   118123.0
# 7               Genf   142963.0   150649.0   161668.0   170992.0   193174.0
# 8                NaN        NaN        NaN        NaN        NaN        NaN
# 9  Espace Mittelland   413572.0   415403.0   483647.0   526353.0   465458.0
#
#         2000       2001       2002       2003    ...           2007  \
# 0        NaN        NaN        NaN        NaN    ...            NaN
# 1        NaN        NaN        NaN        NaN    ...            NaN
# 2  2153280.0  2250931.0  2281650.0  2386989.0    ...      2465306.0
# 3        NaN        NaN        NaN        NaN    ...            NaN
# 4   585420.0   595886.0   630356.0   619304.0    ...       711826.0
# 5   270998.0   268621.0   296781.0   295260.0    ...       321144.0
# 6   111951.0   123166.0   119260.0   124100.0    ...       127923.0
# 7   202471.0   204099.0   214315.0   199944.0    ...       262759.0
# 8        NaN        NaN        NaN        NaN    ...            NaN
# 9   507906.0   527958.0   490598.0   558402.0    ...       567519.0
#
#         2008       2009       2010       2011       2012       2013  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  2494438.0  2528904.0  2665477.0  2687944.0  2726938.0  2779504.0
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4   724511.0   718573.0   759563.0   797756.0   816887.0   831294.0
# 5   318932.0   306453.0   354782.0   364567.0   379764.0   383244.0
# 6   128959.0   139053.0   138911.0   154648.0   159684.0   166382.0
# 7   276620.0   273067.0   265870.0   278541.0   277439.0   281668.0
# 8        NaN        NaN        NaN        NaN        NaN        NaN
# 9   569216.0   572827.0   629224.0   638153.0   620574.0   641341.0
#
#         2014       2015       2016
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2  2826314.0  2860217.0  2938650.0
# 3        NaN        NaN        NaN
# 4   830096.0   845816.0   846266.0
# 5   377345.0   389885.0   386403.0
# 6   167626.0   167396.0   171786.0
# 7   285125.0   288535.0   288077.0
# 8        NaN        NaN        NaN
# 9   646630.0   660222.0   700604.0
#
# [10 rows x 23 columns]

# %% [markdown]
# Was sollen diese vielen NaN Zeilen. Das sind leere Zeilen. Die brauchen wir nicht. Löschen wir sie.

# %%
df.dropna().head()
# Out:
#         Unnamed: 0       1995       1996       1997       1998       1999  \
# 2            Total  1770026.0  1832888.0  2048470.0  2127210.0  2067974.0
# 4  Genferseeregion   479160.0   502708.0   535614.0   556002.0   559787.0
# 5            Waadt   230502.0   242118.0   256017.0   267663.0   248490.0
# 6           Wallis   105695.0   109941.0   117929.0   117347.0   118123.0
# 7             Genf   142963.0   150649.0   161668.0   170992.0   193174.0
#
#         2000       2001       2002       2003    ...           2007  \
# 2  2153280.0  2250931.0  2281650.0  2386989.0    ...      2465306.0
# 4   585420.0   595886.0   630356.0   619304.0    ...       711826.0
# 5   270998.0   268621.0   296781.0   295260.0    ...       321144.0
# 6   111951.0   123166.0   119260.0   124100.0    ...       127923.0
# 7   202471.0   204099.0   214315.0   199944.0    ...       262759.0
#
#         2008       2009       2010       2011       2012       2013  \
# 2  2494438.0  2528904.0  2665477.0  2687944.0  2726938.0  2779504.0
# 4   724511.0   718573.0   759563.0   797756.0   816887.0   831294.0
# 5   318932.0   306453.0   354782.0   364567.0   379764.0   383244.0
# 6   128959.0   139053.0   138911.0   154648.0   159684.0   166382.0
# 7   276620.0   273067.0   265870.0   278541.0   277439.0   281668.0
#
#         2014       2015       2016
# 2  2826314.0  2860217.0  2938650.0
# 4   830096.0   845816.0   846266.0
# 5   377345.0   389885.0   386403.0
# 6   167626.0   167396.0   171786.0
# 7   285125.0   288535.0   288077.0
#
# [5 rows x 23 columns]

# %%
df = df.dropna()

# %%
df.head()
# Out:
#         Unnamed: 0       1995       1996       1997       1998       1999  \
# 2            Total  1770026.0  1832888.0  2048470.0  2127210.0  2067974.0
# 4  Genferseeregion   479160.0   502708.0   535614.0   556002.0   559787.0
# 5            Waadt   230502.0   242118.0   256017.0   267663.0   248490.0
# 6           Wallis   105695.0   109941.0   117929.0   117347.0   118123.0
# 7             Genf   142963.0   150649.0   161668.0   170992.0   193174.0
#
#         2000       2001       2002       2003    ...           2007  \
# 2  2153280.0  2250931.0  2281650.0  2386989.0    ...      2465306.0
# 4   585420.0   595886.0   630356.0   619304.0    ...       711826.0
# 5   270998.0   268621.0   296781.0   295260.0    ...       321144.0
# 6   111951.0   123166.0   119260.0   124100.0    ...       127923.0
# 7   202471.0   204099.0   214315.0   199944.0    ...       262759.0
#
#         2008       2009       2010       2011       2012       2013  \
# 2  2494438.0  2528904.0  2665477.0  2687944.0  2726938.0  2779504.0
# 4   724511.0   718573.0   759563.0   797756.0   816887.0   831294.0
# 5   318932.0   306453.0   354782.0   364567.0   379764.0   383244.0
# 6   128959.0   139053.0   138911.0   154648.0   159684.0   166382.0
# 7   276620.0   273067.0   265870.0   278541.0   277439.0   281668.0
#
#         2014       2015       2016
# 2  2826314.0  2860217.0  2938650.0
# 4   830096.0   845816.0   846266.0
# 5   377345.0   389885.0   386403.0
# 6   167626.0   167396.0   171786.0
# 7   285125.0   288535.0   288077.0
#
# [5 rows x 23 columns]

# %% [markdown]
# Machen wir die Kantone, Regionen zu unserem Index

# %%
df.index = df['Unnamed: 0']

# %%
df.head()
# Out:
#                       Unnamed: 0       1995       1996       1997       1998  \
# Unnamed: 0
# Total                      Total  1770026.0  1832888.0  2048470.0  2127210.0
# Genferseeregion  Genferseeregion   479160.0   502708.0   535614.0   556002.0
# Waadt                      Waadt   230502.0   242118.0   256017.0   267663.0
# Wallis                    Wallis   105695.0   109941.0   117929.0   117347.0
# Genf                        Genf   142963.0   150649.0   161668.0   170992.0
#
#                       1999       2000       2001       2002       2003  \
# Unnamed: 0
# Total            2067974.0  2153280.0  2250931.0  2281650.0  2386989.0
# Genferseeregion   559787.0   585420.0   595886.0   630356.0   619304.0
# Waadt             248490.0   270998.0   268621.0   296781.0   295260.0
# Wallis            118123.0   111951.0   123166.0   119260.0   124100.0
# Genf              193174.0   202471.0   204099.0   214315.0   199944.0
#
#                    ...           2007       2008       2009       2010  \
# Unnamed: 0         ...
# Total              ...      2465306.0  2494438.0  2528904.0  2665477.0
# Genferseeregion    ...       711826.0   724511.0   718573.0   759563.0
# Waadt              ...       321144.0   318932.0   306453.0   354782.0
# Wallis             ...       127923.0   128959.0   139053.0   138911.0
# Genf               ...       262759.0   276620.0   273067.0   265870.0
#
#                       2011       2012       2013       2014       2015  \
# Unnamed: 0
# Total            2687944.0  2726938.0  2779504.0  2826314.0  2860217.0
# Genferseeregion   797756.0   816887.0   831294.0   830096.0   845816.0
# Waadt             364567.0   379764.0   383244.0   377345.0   389885.0
# Wallis            154648.0   159684.0   166382.0   167626.0   167396.0
# Genf              278541.0   277439.0   281668.0   285125.0   288535.0
#
#                       2016
# Unnamed: 0
# Total            2938650.0
# Genferseeregion   846266.0
# Waadt             386403.0
# Wallis            171786.0
# Genf              288077.0
#
# [5 rows x 23 columns]

# %%
df.head()
# Out:
#                       Unnamed: 0       1995       1996       1997       1998  \
# Unnamed: 0
# Total                      Total  1770026.0  1832888.0  2048470.0  2127210.0
# Genferseeregion  Genferseeregion   479160.0   502708.0   535614.0   556002.0
# Waadt                      Waadt   230502.0   242118.0   256017.0   267663.0
# Wallis                    Wallis   105695.0   109941.0   117929.0   117347.0
# Genf                        Genf   142963.0   150649.0   161668.0   170992.0
#
#                       1999       2000       2001       2002       2003  \
# Unnamed: 0
# Total            2067974.0  2153280.0  2250931.0  2281650.0  2386989.0
# Genferseeregion   559787.0   585420.0   595886.0   630356.0   619304.0
# Waadt             248490.0   270998.0   268621.0   296781.0   295260.0
# Wallis            118123.0   111951.0   123166.0   119260.0   124100.0
# Genf              193174.0   202471.0   204099.0   214315.0   199944.0
#
#                    ...           2007       2008       2009       2010  \
# Unnamed: 0         ...
# Total              ...      2465306.0  2494438.0  2528904.0  2665477.0
# Genferseeregion    ...       711826.0   724511.0   718573.0   759563.0
# Waadt              ...       321144.0   318932.0   306453.0   354782.0
# Wallis             ...       127923.0   128959.0   139053.0   138911.0
# Genf               ...       262759.0   276620.0   273067.0   265870.0
#
#                       2011       2012       2013       2014       2015  \
# Unnamed: 0
# Total            2687944.0  2726938.0  2779504.0  2826314.0  2860217.0
# Genferseeregion   797756.0   816887.0   831294.0   830096.0   845816.0
# Waadt             364567.0   379764.0   383244.0   377345.0   389885.0
# Wallis            154648.0   159684.0   166382.0   167626.0   167396.0
# Genf              278541.0   277439.0   281668.0   285125.0   288535.0
#
#                       2016
# Unnamed: 0
# Total            2938650.0
# Genferseeregion   846266.0
# Waadt             386403.0
# Wallis            171786.0
# Genf              288077.0
#
# [5 rows x 23 columns]

# %% [markdown]
# Jetzt rufen wir nur eine Kolonne auf

# %%
df[1995]

# %% [markdown]
# Wenn wir Reihen entfernen wollen

# %%
df.drop(['Nordwestschweiz'])
# Appenzell I. Rh.      1429.0     1567.0
# St. Gallen          137789.0   139227.0
# Graubünden           42426.0    46322.0
# Thurgau              69838.0    70921.0
# Zentralschweiz      172486.0   174658.0
# Luzern               93489.0    95423.0
# Uri                   5291.0     5040.0
# Schwyz               32642.0    33296.0
# Obwalden              6206.0     6035.0
# Nidwalden             7008.0     6960.0
# Zug                  27850.0    27904.0
# Tessin              166555.0   178987.0
#
# [31 rows x 23 columns]

# %% [markdown]
# Bauen wir eine neue Column mit dem Wert aus 2016 und dem Wert aus 1996

# %%
df['Differenz'] = df[2016] - df[1996]

# %% [markdown]
# Schauen wir uns das Resultat an

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Total to Tessin
# Data columns (total 25 columns):
# Unnamed: 0    32 non-null object
# 1995          32 non-null float64
# 1996          32 non-null float64
# 1997          32 non-null float64
# 1998          32 non-null float64
# 1999          32 non-null float64
# 2000          32 non-null float64
# 2001          32 non-null float64
# 2002          32 non-null float64
# 2003          32 non-null float64
# 2004          32 non-null float64
# 2005          32 non-null float64
# 2006          32 non-null float64
# 2007          32 non-null float64
# 2008          32 non-null float64
# 2009          32 non-null float64
# 2010          32 non-null float64
# 2011          32 non-null float64
# 2012          32 non-null float64
# 2013          32 non-null float64
# 2014          32 non-null float64
# 2015          32 non-null float64
# 2016          32 non-null float64
# Differenz     32 non-null float64
# Prozent       32 non-null float64
# dtypes: float64(24), object(1)
# memory usage: 6.5+ KB

# %% [markdown]
# Rechnen wir den Prozentanteil der Steigerung zum jetzigen Konkursmasse, also von 2016

# %%
df['Prozent'] = round(df['Differenz'] / df[2016] * 100, 1)

# %% [markdown]
# Sortieren wir es

# %%
df['Prozent'].sort_values(ascending=False)
# Out:
# Unnamed: 0
# Genf                 47.7
# Freiburg             46.4
# Basel-Landschaft     44.1
# Neuenburg            43.8
# Zug                  43.4
# Solothurn            42.1
# Espace Mittelland    40.7
# Genferseeregion      40.6
# Uri                  40.1
# Zürich               38.6
# Obwalden             38.2
# Bern                 38.0
# Total                37.6
# Glarus               37.4
# Waadt                37.3
# Basel-Stadt          37.3
# Wallis               36.0
# Nordwestschweiz      35.9
# Zentralschweiz       35.7
# Schwyz               34.4
# Luzern               34.2
# Appenzell A. Rh.     33.3
# Schaffhausen         33.1
# St. Gallen           32.9
# Aargau               31.2
# Jura                 30.7
# Tessin               29.9
# Ostschweiz           28.4
# Nidwalden            27.3
# Thurgau              22.0
# Graubünden           19.4
# Appenzell I. Rh.     18.4
# Name: Prozent, dtype: float64

# %% [markdown]
# Bauen wir damit eine neue Tabelle

# %%
pd.DataFrame(df['Prozent'].sort_values(ascending=False))
# Out:
#                    Prozent
# Unnamed: 0
# Genf                  47.7
# Freiburg              46.4
# Basel-Landschaft      44.1
# Neuenburg             43.8
# Zug                   43.4
# Solothurn             42.1
# Espace Mittelland     40.7
# Genferseeregion       40.6
# Uri                   40.1
# Zürich                38.6
# Obwalden              38.2
# Bern                  38.0
# Total                 37.6
# Glarus                37.4
# Waadt                 37.3
# Basel-Stadt           37.3
# Wallis                36.0
# Nordwestschweiz       35.9
# Zentralschweiz        35.7
# Schwyz                34.4
# Luzern                34.2
# Appenzell A. Rh.      33.3
# Schaffhausen          33.1
# St. Gallen            32.9
# Aargau                31.2
# Jura                  30.7
# Tessin                29.9
# Ostschweiz            28.4
# Nidwalden             27.3
# Thurgau               22.0
# Graubünden            19.4
# Appenzell I. Rh.      18.4

# %% [markdown]
# ## 4. Matplotlib

# %% [markdown]
# Importieren wir die neue Library

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
pd.DataFrame(df['Prozent'].sort_values(ascending=True)).plot()

# %% [markdown]
# Stellen wir das etwas anders dar

# %%
pd.DataFrame(df['Prozent'].sort_values(ascending=True)).plot(kind='bar')

# %% [markdown]
# [Gallerie der vielen Darstellungsformen](http://matplotlib.org/gallery.html)

# %% [markdown]
# Schauen wir uns das etwas anders an, und definieren wir, wie gross es sein soll

# %%
pd.DataFrame(df['Prozent'].sort_values(ascending=True)).plot(kind='barh', figsize=(5,7))

# %% [markdown]
# Setzen wir einen Titel

# %%
fig, ax = plt.subplots(figsize =(7,5))
ax.set_title("Pronzentuelle Steigerung der Betreibungen nach Kanton, 2006 - 2016")
pd.DataFrame(df['Prozent'].sort_values(ascending=True)).plot(kind='barh', figsize=(5,7), ax=ax)

# %% [markdown]
# Und drucken wir das ganze aus

# %%
fig, ax = plt.subplots(figsize =(7,5))
ax.set_title("Pronzentuelle Steigerung der Betreibungen nach Kanton, 2006 - 2016")
pd.DataFrame(df['Prozent'].sort_values(ascending=True)).plot(kind='barh', figsize=(5,7), ax=ax)
plt.savefig('Steigerung.pdf', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## 5. Merging

# %% [markdown]
# Jetzt wollen wir verstehen, welcher Kanton pro Haushalt am meisten Betreibungen hat? Laden wir uns die Daten [aus den Datacubes des BFS herunter](https://www.pxweb.bfs.admin.ch). "Privathaushalte nach institutionellen Gliederungen und Haushaltsgrösse"

# %%
df_haushalte = pd.read_csv('haushalt_2015.csv')

# %%
df_haushalte.head()
del df_haushalte['Unnamed: 2']
del df_haushalte['Unnamed: 3']

# %%
df_haushalte.head()

# %% [markdown]
# Jetzt verbinden wir sie

# %%
df

# %%
df_haushalte = df_haushalte.merge(df, left_on='Kanton', right_on='Unnamed: 0')

# %%
df_haushalte.head()

# %% [markdown]
# Rechnen wir aus, wieviele Betreibungen pro Haushalt.

# %%
df_haushalte['Betreibungen pro Haushalt'] = round(df_haushalte['2015'] / df_haushalte[2015],1 )

# %%
df_haushalte[['Kanton', 'Betreibungen pro Haushalt']]

# %% [markdown]
# Sortieren wir sie.

# %%
df_haushalte[['Kanton', 'Betreibungen pro Haushalt']].sort_values(by='Betreibungen pro Haushalt', ascending=False)
